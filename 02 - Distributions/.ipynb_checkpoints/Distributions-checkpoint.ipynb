# %% [markdown]
# # Distribution functions in Python
#
#
# ### This notebook is licensed  under [CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/?ref=chooser-v1) © 2024 by Xavier Luri (ICCUB)
#
#
# from _scipy.stats_ : https://docs.scipy.org/doc/scipy/reference/stats.html
#
# ## Probability Density Functions (PDF) and Cumulative Distribution functions (CDF)
#
# * PDF: $P(a \leq x \leq b) = \int_a^b f(x) \, dx$
#
# * CDF:  cdf(y) = $P(x \leq y) = \int_{-\infty}^y f(x) \, dx$
#
# ### 1- Normal distribution

# %%
# %matplotlib inline
import scipy.stats as scp
import matplotlib.pyplot as plt
import numpy as np

N = 100
min = -6.
max = 6.
x = np.linspace(min, max,N) # N points from min to max
fig = plt.figure(frameon=False)
fig.set_size_inches(15,7.5)

# ----------
# Plot PDFs 
# ----------
p1= plt.subplot(1,2,1)

mu,sig = 0.,1.
plt.plot(x, scp.norm.pdf(x,mu,sig),'r-', lw=2, label='norm')
mu,sig = 0.,2.
plt.plot(x, scp.norm.pdf(x,mu,sig),'g-', lw=2, label='norm')
mu,sig = 0.,3.
plt.plot(x, scp.norm.pdf(x,mu,sig),'b-', lw=2, label='norm')

plt.ylabel('PDF')
plt.xlabel('x')

# ----------
# Plot CDFs 
# ----------
p1= plt.subplot(1,2,2)

mu,sig = 0.,1.
plt.plot(x, scp.norm.cdf(x,mu,sig),'r-', lw=2, label='norm')
mu,sig = 0.,2.
plt.plot(x, scp.norm.cdf(x,mu,sig),'g-', lw=2, label='norm')
mu,sig = 0.,3.
plt.plot(x, scp.norm.cdf(x,mu,sig),'b-', lw=2, label='norm')

plt.ylabel('CDF')
plt.xlabel('x')

plt.show()

# %% [markdown]
# ### 2 - $\chi^2$ distribution

# %%
# %matplotlib inline
import scipy.stats as scp
import matplotlib.pyplot as plt
import numpy as np

N = 100
min = 0.
max = 15.
x = np.linspace(min, max,N) # N points from min to max
fig = plt.figure(frameon=False)
fig.set_size_inches(15,7.5)

# ----------
# Plot PDFs 
# ----------
p1= plt.subplot(1,2,1)

k = 2
plt.plot(x, scp.chi2.pdf(x,k),'r-', lw=2, label='chi2')
k = 3
plt.plot(x, scp.chi2.pdf(x,k),'g-', lw=2, label='chi2')
k = 4
plt.plot(x, scp.chi2.pdf(x,k),'b-', lw=2, label='chi2')
k = 5
plt.plot(x, scp.chi2.pdf(x,k),'y-', lw=2, label='chi2')

plt.ylabel('PDF')
plt.xlabel('x')

# ----------
# Plot PDFs 
# ----------
p1= plt.subplot(1,2,2)

k = 2
plt.plot(x, scp.chi2.cdf(x,k),'r-', lw=2, label='chi2')
k = 3
plt.plot(x, scp.chi2.cdf(x,k),'g-', lw=2, label='chi2')
k = 4
plt.plot(x, scp.chi2.cdf(x,k),'b-', lw=2, label='chi2')
k = 5
plt.plot(x, scp.chi2.cdf(x,k),'y-', lw=2, label='chi2')

plt.ylabel('CDF')
plt.xlabel('x')

plt.show()

# %% [markdown]
# ### 3 - Cauchy distribution

# %%
# %matplotlib inline
import scipy.stats as scp
import matplotlib.pyplot as plt
import numpy as np

N = 100
min = -7.
max = 7.
x = np.linspace(min, max,N) # N points from min to max
fig = plt.figure(frameon=False)
fig.set_size_inches(15,7.5)

# ----------
# Plot PDFs 
# ----------
p1= plt.subplot(1,2,1)

mean, scale = 0., 1.
plt.plot(x, scp.cauchy.pdf(x,mean,scale),'r-', lw=2, label='cauchy')
mean, scale = 0., 2.
plt.plot(x, scp.cauchy.pdf(x,mean,scale),'g-', lw=2, label='cauchy')
mean, scale = 0., 3.
plt.plot(x, scp.cauchy.pdf(x,mean,scale),'b-', lw=2, label='cauchy')

plt.title('PDF')
plt.xlabel('x')

# ----------
# Plot CDFs 
# ----------
p1= plt.subplot(1,2,2)

mean, scale = 0., 1.
plt.plot(x, scp.cauchy.cdf(x,mean,scale),'r-', lw=2, label='cauchy')
mean, scale = 0., 2.
plt.plot(x, scp.cauchy.cdf(x,mean,scale),'g-', lw=2, label='cauchy')
mean, scale = 0., 3.
plt.plot(x, scp.cauchy.cdf(x,mean,scale),'b-', lw=2, label='cauchy')

plt.title('CDF')
plt.xlabel('x')


plt.show()

# %% [markdown]
# ###  4 - Beta distribution
#
# Wikipedia: "The beta distribution has been applied to model the behavior of random variables limited to intervals of finite length in a wide variety of disciplines."

# %%
# %matplotlib inline
import scipy.stats as scp
import matplotlib.pyplot as plt
import numpy as np

N = 100
min = 0.
max = 1.
x = np.linspace(min, max,N) # N points from min to max
fig = plt.figure(frameon=False)
fig.set_size_inches(15,7.5)

# ----------
# Plot PDFs 
# ----------
p1= plt.subplot(1,2,1)

a,b = 0.5,0.5
plt.plot(x, scp.beta.pdf(x,a,b),'r-', lw=2, label='beta')
a,b = 5.,1.
plt.plot(x, scp.beta.pdf(x,a,b),'b-', lw=2, label='beta')
a,b = 1.,3.
plt.plot(x, scp.beta.pdf(x,a,b),'g-', lw=2, label='beta')
a,b = 2.,2.
plt.plot(x, scp.beta.pdf(x,a,b),'y-', lw=2, label='beta')

plt.title('PDF')
plt.xlabel('x')

# ----------
# Plot CDFs 
# ----------
p1= plt.subplot(1,2,2)

# Beta distribution
a,b = 0.5,0.5
plt.plot(x, scp.beta.cdf(x,a,b),'r-', lw=2, label='beta')
a,b = 5.,1.
plt.plot(x, scp.beta.cdf(x,a,b),'b-', lw=2, label='beta')
a,b = 1.,3.
plt.plot(x, scp.beta.cdf(x,a,b),'g-', lw=2, label='beta')
a,b = 2.,2.
plt.plot(x, scp.beta.cdf(x,a,b),'y-', lw=2, label='beta')

plt.title('CDF')
plt.xlabel('x')

plt.show()

# %% [markdown]
# ### Calculating probabilities: integration vs. CDF
#
# By definition, the proability of a random variable to be in the interval $[x_1,x_2]$ is:
#
# $P(x_1 \leq x \leq x_2) = \int_{x_1}^{x_2} f(x) \; dx$
#
# where $f(x)$ is the PDF. Let's implement this with a normal distribution.

# %%
import scipy.stats as scp
import scipy.integrate as integrate

mu,sig = 0.,1.
Pint= integrate.quad(lambda x: scp.norm.pdf(x,mu,sig), -sig, sig)
print("P(",-sig,",",sig,")=",Pint[0],"+/-",Pint[1])
# Out:
# P( -1.0 , 1.0 )= 0.682689492137086 +/- 7.579375928402476e-15

# %% [markdown]
# Now, we can repeat the calculation using the CDF. Following the definition of the CDF:
#
# $cdf(y) = P(x \leq y) = \int_{-\infty}^y f(x) \, dx$
#
# it follows that:
#
# $P(x_1 \leq x \leq x_2) = \int_{x_1}^{x_2} f(x) \; dx = cdf(x_2)-cdf(x_1)$
#
# Let's use this property:

# %%
import scipy.stats as scp

mu,sig = 0.,1.
Pcdf= scp.norm.cdf(sig,mu,sig) - scp.norm.cdf(-sig,mu,sig)

print("P(",-sig,",",sig,")=",Pcdf)
# Out:
# P( -1.0 , 1.0 )= 0.6826894921370859

# %% [markdown]
# And the difference

# %%
print("Pint-Pcdf= ",Pint[0]-Pcdf)
# Out:
# Pint-Pcdf=  1.1102230246251565e-16
